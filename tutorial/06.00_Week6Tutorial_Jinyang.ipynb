# %% [markdown]
# # <center> APIs and JSON </center>
#
# Today we'll learn more about collecting data from the web, and a new data structure: JSON.
#
#
# ## Skills Covered
#
# * Dictionaries
# * Get requests
# * Parsing JSON (really just elaborate dictionaries)

# %% [markdown]
# ## Dictionaries
#
# A *dictionary* in Python is an unordered collection of data values, used to store data values like a map, which unlike other Data Types that hold only single value as an element, a *dictionary* holds key:value pairs.
#
# Like lists, dictionaries can easily be changed, can be shrunk and grown ad libitum at run time. They shrink and grow without the necessity of making copies. Dictionaries can be contained in lists and vice versa.
#
# But what's the difference between lists and dictionaries? Lists are ordered sets of objects, whereas dictionaries are unordered sets. But the main difference is that items in dictionaries are accessed via keys and not via their position. A dictionary is an associative array (also known as hashes). Any key of the dictionary is associated (or mapped) to a value. The values of a dictionary can be any Python data type. So dictionaries are unordered key-value-pairs.
#
# We will use dictionaries to access APIs, and we will see them again when we learn how to count words.

# %%
my_dict = {'education': 'high school',
          'income': 60000}
type(my_dict)
# Out:
# dict

# %%
my_dict

# %% [markdown]
# The key is before the colon, the value is after the colon.
#
# Find all the keys from the dictionary, and then all the values.

# %%
my_dict.keys()

# %%
my_dict.values()

# %% [markdown]
# We can access keys using the bracket syntax. We've seen this before (remember columns in Pandas?). The input is a dictionary key, the output is the key's value.

# %%
my_dict['education']
# Out:
# 'high school'

# %%
my_dict['income']

# %% [markdown]
# We can add key/value pairs using the bracket syntax and the assignment operator. Notice the order of the key/value pairs does not matter, like they do in lists and strings.

# %%
my_dict['age'] = 24
my_dict

# %% [markdown]
# # <center> Accessing Databases via Web APIs </center>
# * * * * *
#
# This tutorial comes from my colleague [Chris Hensch](https://henchc.github.io/). Thanks Chris!
#
# His motivating question: he thinks Duke Ellington is 'trending' as of late. We're going to test this theory via the number of articles that mention him in the NYT.
#
# If you want to try the Twitter API or other web scraping techniques, I recommend [Brian Keegan's detailed 5-week web scraping and API tutorial](https://github.com/CU-ITSS/Web-Data-Scraping-S2019).
#
# Here's another [Twitter API tutorial using the Python library Tweepy](https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/twitter-data-in-python/) (you can install it via Anaconda), for those who want to explore Twitter data.

# %% [markdown]
# ## APIs

# %%
# Import required libraries
import requests #requests library, enables get requests
import json #data structure, similar to dictionaries
import time #pause between pings to server
import pandas #we know this one!

# %% [markdown]
# ## 1. Constructing API GET Request
# *****
#
# First, [y'all need to set up a New York Times developer account](https://developer.nytimes.com/accounts/create), and then get an API key.
#
# In the first place, we know that every call will require us to provide:
#
# 1. a base URL for the API, and
# 2. some authorization code or key.
#
# So let's store those in some variables.

# %% [markdown]
# To get the base url, we can simply use the [documentation](https://developer.nytimes.com/). The New York Times has a lot of different APIs. If we scroll down, the second one is the [Article Search API](https://developer.nytimes.com/docs/articlesearch-product/1/overview), which is what we want. From that page we can find the url. Now let's assign it to a variable.

# %%
# set base url
base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

# %%
# set key: copy and past your NYTimes API key here
key = "ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM"

# %% [markdown]
# For many API's, you'll have to specify the response format, such as xml or JSON. But for this particular API, the only possible response format is JSON, as we can see in the url, so we don't have to name it explicitly.

# %% [markdown]
# Now we need to send some sort of data in the URL’s query string. This data tells the API what information we want. In our case, we want articles about Duke Ellington. Requests allows you to provide these arguments as a dictionary, using the `params` keyword argument. In addition to the search term `q`, we have to put in the `api-key` term.

# %%
# set search parameters
search_params = {'q': 'Duke Ellington',
                "api-key": key}

# %% [markdown]
# Now we're ready to make the request. We use the `.get` method from the `requests` library to make an HTTP GET Request.
#
# Let's pause to discuss what a GET request is.

# %%
# make request
r = requests.get(base_url, params=search_params)

# %% [markdown]
# Now, we have a [response](http://docs.python-requests.org/en/latest/api/#requests.Response) object called `r`. We can get all the information we need from this object. For instance, we can see that the URL has been correctly encoded by printing the URL. Click on the link to see what happens.

# %%
#view the response url
r.url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Duke+Ellington&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM'

# %% [markdown]
# Click on that link to see what it returns!
#
# It's not very pleasant looking, but in the next section we will work on parsing it into something more palatable. For now let's try adding some parameters to our search.

# %% [markdown]
# ### Adding a date range
#
# What if we only want to search within a particular date range? The NYT Article Search API allows us to specify start and end dates.
#
# We can alter `search_params` so that the request only searches for articles in the year 2016. Remember, since `search_params` is a dictionary! (You know dictionaries :) ). we can simply add the new key/value pairs to it.
#
# Use the [documentation](https://developer.nytimes.com/article_search_v2.json#/Documentation/GET/articlesearch.json) to see how to format the new parameters. Note the data types for each field. Note also that the paramaters are in the form of a dictionary. Remember how to add a key/value pair in a dictionary.

# %%
# add begin data and end date key/value pairs 
search_params["begin_date"] = "20160101"
search_params["end_date"] = "20161231"

# %%
# Re-run the get request and inspect the output, again by getting the url
r = requests.get(base_url, params = search_params)
r.url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Duke+Ellington&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20160101&end_date=20161231'

# %% [markdown]
# ### Challenge 2:  Specifying a results page
#
# The above will return the first 10 results. To get the next ten, you need to add a "page" parameter. Change the search parameters above to get the second 10 results.

# %%
# set page parameters here
search_params['page'] = 1
search_params
# Out:
# {'q': 'Duke Ellington',
#  'api-key': 'ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM',
#  'begin_date': '20160101',
#  'end_date': '20161231',
#  'page': 1}

# %%
# re-run the get request with new parameters
# let's add a pause as well, to not overload the server

r = requests.get(base_url, params = search_params)
time.sleep(5)
r.url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Duke+Ellington&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20160101&end_date=20161231&page=1'

# %% [markdown]
# ## 2. Parsing the response text
# *****

# %% [markdown]
# We can read the content of the server’s response using `.text` from `requests`.

# %%
# Inspect the content of the response, parsing the result as text
response_text = r.text
response_text[:1000]
# Out:
# '{"status":"OK","copyright":"Copyright (c) 2023 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.","web_url":"https://www.nytimes.com/2016/04/04/arts/music/review-wynton-marsaliss-spaces-a-kinetic-series-of-zoological-portraits.html","snippet":"In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.","lead_paragraph":"The kazoos cropped up in the 10th and final movement of “Spaces,” an episodic suite by Wynton Marsalis that had its world premiere at the Rose Theater on Friday. The Jazz at Lincoln Center Orchestra was swinging light and fast as it happened, bzz-bzz-bzz-bzz-bzz, in a busy rush. It was a cute and clever flourish, in a piece titled “Bees Bees Bees.” And it was also an act of e'

# %% [markdown]
# What you see here is JSON text, encoded as unicode text. JSON stands for "Javascript object notation." It has a very similar structure to a python dictionary -- both are built on key/value pairs. This makes it easy to convert JSON response to a python dictionary. We do this with the `json.loads()` function.

# %%
# Convert JSON response to a dictionary and view
data = json.loads(response_text)
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#     'web_url': 'https://www.nytimes.com/2016/04/04/arts/music/review-wynton-marsaliss-spaces-a-kinetic-series-of-zoological-portraits.html',
#     'snippet': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#     'lead_paragraph': 'The kazoos cropped up in the 10th and final movement of “Spaces,” an episodic suite by Wynton Marsalis that had its world premiere at the Rose Theater on Friday. The Jazz at Lincoln Center Orchestra was swinging light and fast as it happened, bzz-bzz-bzz-bzz-bzz, in a busy rush. It was a cute and clever flourish, in a piece titled “Bees Bees Bees.” And it was also an act of evocation that reflected the larger theme of the suite.',
#     'print_section': 'C',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Music',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Dancing', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Jazz', 'rank': 4, 'major': 'N'},
#      {'name': 'persons', 'value': 'Marsalis, Wynton', 'rank': 5, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Spaces (Musical Work)',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Jazz at Lincoln Center',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Jazz at Lincoln Center Orchestra',
#       'rank': 8,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Rose Theater',
#       'rank': 9,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Grimes, Jared', 'rank': 10, 'major': 'N'},
#      {'name': 'persons', 'value': 'Lil Buck', 'rank': 11, 'major': 'N'},
#      {'name': 'persons', 'value': 'Sneed, Damien', 'rank': 12, 'major': 'N'}],
#     'pub_date': '2016-04-03T22:54:49+0000',
#     'document_type': 'article',
#     'news_desk': 'Culture',
#     'section_name': 'Arts',
#     'subsection_name': 'Music',
#     'byline': {'original': 'By Nate Chinen',
#      'person': [{'firstname': 'Nate',
#        'middlename': None,
#        'lastname': 'Chinen',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Review',
#     '_id': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a',
#     'word_count': 423,
#     'uri': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a'},
#    {'abstract': 'Most members of a 20-piece band that plays regularly in Sheepshead Bay learned jazz clandestinely in Soviet-era Russia, where the authorities were suspicious of people interested in American culture.',
#     'web_url': 'https://www.nytimes.com/2016/05/17/nyregion/in-a-brooklyn-basement-jazz-with-a-russian-accent.html',
#     'snippet': 'Most members of a 20-piece band that plays regularly in Sheepshead Bay learned jazz clandestinely in Soviet-era Russia, where the authorities were suspicious of people interested in American culture.',
#     'lead_paragraph': 'In the 1960s and ’70s in Moscow, Nina Brodskaya was a singing star.',
#     'print_section': 'A',
#     'print_page': '18',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbWide.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-verticalTwoByThree735.jpg',
#       'height': 1102,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 400},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog480.jpg',
#       'height': 320,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog427.jpg',
#       'height': 285,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-tmagArticle.jpg',
#       'height': 395,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-jumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master675.jpg',
#       'height': 450,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master180.jpg',
#       'height': 120,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master768.jpg',
#       'height': 512,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-popup.jpg',
#       'height': 433,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog533.jpg',
#       'height': 355,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-tmagSF.jpg',
#       'height': 241,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-slide.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-superJumbo.jpg',
#       'height': 1365,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master1050.jpg',
#       'height': 700,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master495.jpg',
#       'height': 330,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master315.jpg',
#       'height': 210,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleInline.jpg',
#       'height': 127,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-hpSmall.jpg',
#       'height': 109,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blogSmallInline.jpg',
#       'height': 101,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumFlexible177.jpg',
#       'height': 118,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-hpLarge.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeWidescreen1050.jpg',
#       'height': 590,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine3000.jpg',
#       'height': 1687,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNineJumbo1600.jpg',
#       'height': 900,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'}],
#     'headline': {'main': 'In a Brooklyn Basement, Jazz With a Russian Accent',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'In a Brooklyn Basement, Jazz With a Russian Accent',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Russian-Americans',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'glocations',
#       'value': 'USSR (Former Soviet Union)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Music', 'rank': 4, 'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Brighton Beach (Brooklyn, NY)',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Jazz', 'rank': 6, 'major': 'N'}],
#     'pub_date': '2016-05-16T14:56:32+0000',
#     'document_type': 'article',
#     'news_desk': 'Metro',
#     'section_name': 'New York',
#     'byline': {'original': 'By Corey Kilgannon',
#      'person': [{'firstname': 'Corey',
#        'middlename': None,
#        'lastname': 'Kilgannon',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/a7939e5d-f0ec-5b85-8375-95c0e24fe674',
#     'word_count': 1157,
#     'uri': 'nyt://article/a7939e5d-f0ec-5b85-8375-95c0e24fe674'},
#    {'abstract': 'Tom Manuel, a trumpeter, has founded a new exhibition, preservation and performance space housing his collection of at least 10,000 pieces of memorabilia.',
#     'web_url': 'https://www.nytimes.com/2016/05/22/nyregion/jazz-loft-housing-a-trove-of-memorabilia-opens-in-stony-brook.html',
#     'snippet': 'Tom Manuel, a trumpeter, has founded a new exhibition, preservation and performance space housing his collection of at least 10,000 pieces of memorabilia.',
#     'lead_paragraph': 'As a teenage trumpeter who loved jazz, Tom Manuel would visit the Dunton Inn, a local spot in East Patchogue where a group of old-timers — some of whom had played alongside Tommy Dorsey, Harry James and Louis Armstrong — would let the untried kid from Lake Ronkonkoma sit in during weekly jam sessions.',
#     'print_section': 'LI',
#     'print_page': '9',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-thumbWide.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-verticalTwoByThree735.jpg',
#       'height': 1103,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 400},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog480.jpg',
#       'height': 320,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog427.jpg',
#       'height': 285,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-tmagArticle.jpg',
#       'height': 395,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-jumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master675.jpg',
#       'height': 450,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master180.jpg',
#       'height': 120,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master768.jpg',
#       'height': 512,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-popup.jpg',
#       'height': 433,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog533.jpg',
#       'height': 355,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-tmagSF.jpg',
#       'height': 241,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-slide.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-superJumbo.jpg',
#       'height': 1365,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master1050.jpg',
#       'height': 700,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master495.jpg',
#       'height': 330,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master315.jpg',
#       'height': 210,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleInline.jpg',
#       'height': 127,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-hpSmall.jpg',
#       'height': 109,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blogSmallInline.jpg',
#       'height': 101,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumFlexible177.jpg',
#       'height': 118,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-hpLarge.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeWidescreen1050.jpg',
#       'height': 590,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
# ...
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master768.jpg',
#       'height': 512,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-popup.jpg',
#       'height': 433,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blog533.jpg',
#       'height': 355,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-tmagSF.jpg',
#       'height': 241,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-slide.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-superJumbo.jpg',
#       'height': 1365,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master1050.jpg',
#       'height': 700,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master495.jpg',
#       'height': 330,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master315.jpg',
#       'height': 210,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-articleInline.jpg',
#       'height': 127,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-hpSmall.jpg',
#       'height': 109,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blogSmallInline.jpg',
#       'height': 101,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-mediumFlexible177.jpg',
#       'height': 118,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-hpLarge.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNineJumbo1600.jpg',
#       'height': 900,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'}],
#     'headline': {'main': 'Review: Cecil Taylor’s Mysteries Don’t Resolve at the 88th Key',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A Pianist’s Mysteries  Do Not Resolve  at the 88th Key',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Music',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Whitney Museum of American Art',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Jazz', 'rank': 4, 'major': 'N'},
#      {'name': 'persons', 'value': 'Tanaka, Min', 'rank': 5, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Cecil Taylor: Open Plan (Exhibit)',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Taylor, Cecil', 'rank': 7, 'major': 'N'}],
#     'pub_date': '2016-04-15T20:57:11+0000',
#     'document_type': 'article',
#     'news_desk': 'Culture',
#     'section_name': 'Arts',
#     'subsection_name': 'Music',
#     'byline': {'original': 'By Ben Ratliff',
#      'person': [{'firstname': 'Ben',
#        'middlename': None,
#        'lastname': 'Ratliff',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Review',
#     '_id': 'nyt://article/20d00e40-9af0-59b5-bad5-2b9b0ef725e7',
#     'word_count': 797,
#     'uri': 'nyt://article/20d00e40-9af0-59b5-bad5-2b9b0ef725e7'}],
#   'meta': {'hits': 47, 'offset': 10, 'time': 22}}}

# %% [markdown]
# That looks intimidating! But it's really just a big dictionary. Let's see what keys we got in there.

# %%
#How do we find all the keys associated with a dictionary? We know that!

data.keys()
# Out:
# dict_keys(['status', 'copyright', 'response'])

# %%
#get the value by calling the key
data['copyright']
# Out:
# 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.'

# %%
#very uninteresting
data['status']
# Out:
# 'OK'

# %%
# lots contained in the response column!
data['response']
# Out:
# {'docs': [{'abstract': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#    'web_url': 'https://www.nytimes.com/2016/04/04/arts/music/review-wynton-marsaliss-spaces-a-kinetic-series-of-zoological-portraits.html',
#    'snippet': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#    'lead_paragraph': 'The kazoos cropped up in the 10th and final movement of “Spaces,” an episodic suite by Wynton Marsalis that had its world premiere at the Rose Theater on Friday. The Jazz at Lincoln Center Orchestra was swinging light and fast as it happened, bzz-bzz-bzz-bzz-bzz, in a busy rush. It was a cute and clever flourish, in a piece titled “Bees Bees Bees.” And it was also an act of evocation that reflected the larger theme of the suite.',
#    'print_section': 'C',
#    'print_page': '4',
#    'source': 'The New York Times',
#    'multimedia': [],
#    'headline': {'main': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#     'kicker': None,
#     'content_kicker': None,
#     'print_headline': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#     'name': None,
#     'seo': None,
#     'sub': None},
#    'keywords': [{'name': 'subject', 'value': 'Music', 'rank': 1, 'major': 'N'},
#     {'name': 'subject', 'value': 'Dancing', 'rank': 3, 'major': 'N'},
#     {'name': 'subject', 'value': 'Jazz', 'rank': 4, 'major': 'N'},
#     {'name': 'persons', 'value': 'Marsalis, Wynton', 'rank': 5, 'major': 'N'},
#     {'name': 'creative_works',
#      'value': 'Spaces (Musical Work)',
#      'rank': 6,
#      'major': 'N'},
#     {'name': 'organizations',
#      'value': 'Jazz at Lincoln Center',
#      'rank': 7,
#      'major': 'N'},
#     {'name': 'organizations',
#      'value': 'Jazz at Lincoln Center Orchestra',
#      'rank': 8,
#      'major': 'N'},
#     {'name': 'organizations',
#      'value': 'Rose Theater',
#      'rank': 9,
#      'major': 'N'},
#     {'name': 'persons', 'value': 'Grimes, Jared', 'rank': 10, 'major': 'N'},
#     {'name': 'persons', 'value': 'Lil Buck', 'rank': 11, 'major': 'N'},
#     {'name': 'persons', 'value': 'Sneed, Damien', 'rank': 12, 'major': 'N'}],
#    'pub_date': '2016-04-03T22:54:49+0000',
#    'document_type': 'article',
#    'news_desk': 'Culture',
#    'section_name': 'Arts',
#    'subsection_name': 'Music',
#    'byline': {'original': 'By Nate Chinen',
#     'person': [{'firstname': 'Nate',
#       'middlename': None,
#       'lastname': 'Chinen',
#       'qualifier': None,
#       'title': None,
#       'role': 'reported',
#       'organization': '',
#       'rank': 1}],
#     'organization': None},
#    'type_of_material': 'Review',
#    '_id': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a',
#    'word_count': 423,
#    'uri': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a'},
#   {'abstract': 'Most members of a 20-piece band that plays regularly in Sheepshead Bay learned jazz clandestinely in Soviet-era Russia, where the authorities were suspicious of people interested in American culture.',
#    'web_url': 'https://www.nytimes.com/2016/05/17/nyregion/in-a-brooklyn-basement-jazz-with-a-russian-accent.html',
#    'snippet': 'Most members of a 20-piece band that plays regularly in Sheepshead Bay learned jazz clandestinely in Soviet-era Russia, where the authorities were suspicious of people interested in American culture.',
#    'lead_paragraph': 'In the 1960s and ’70s in Moscow, Nina Brodskaya was a singing star.',
#    'print_section': 'A',
#    'print_page': '18',
#    'source': 'The New York Times',
#    'multimedia': [{'rank': 0,
#      'subtype': 'watch308',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-watch308.jpg',
#      'height': 348,
#      'width': 312,
#      'legacy': {},
#      'subType': 'watch308',
#      'crop_name': 'watch308'},
#     {'rank': 0,
#      'subtype': 'watch268',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-watch268.jpg',
#      'height': 303,
#      'width': 272,
#      'legacy': {},
#      'subType': 'watch268',
#      'crop_name': 'watch268'},
#     {'rank': 0,
#      'subtype': 'wide',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbWide.jpg',
#      'height': 126,
#      'width': 190,
#      'legacy': {'widewidth': 190,
#       'wideheight': 126,
#       'wide': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbWide.jpg'},
#      'subType': 'wide',
#      'crop_name': 'thumbWide'},
#     {'rank': 0,
#      'subtype': 'videoThumb',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoThumb.jpg',
#      'height': 50,
#      'width': 75,
#      'legacy': {},
#      'subType': 'videoThumb',
#      'crop_name': 'videoThumb'},
#     {'rank': 0,
#      'subtype': 'videoLarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoLarge.jpg',
#      'height': 507,
#      'width': 768,
#      'legacy': {},
#      'subType': 'videoLarge',
#      'crop_name': 'videoLarge'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo210',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo210.jpg',
#      'height': 140,
#      'width': 210,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo210',
#      'crop_name': 'mediumThreeByTwo210'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo225',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo225.jpg',
#      'height': 150,
#      'width': 225,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo225',
#      'crop_name': 'mediumThreeByTwo225'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo440',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo440.jpg',
#      'height': 293,
#      'width': 440,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo440',
#      'crop_name': 'mediumThreeByTwo440'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo252',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo252.jpg',
#      'height': 168,
#      'width': 252,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo252',
#      'crop_name': 'mediumThreeByTwo252'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo378',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo378.jpg',
#      'height': 252,
#      'width': 378,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo378',
#      'crop_name': 'mediumThreeByTwo378'},
#     {'rank': 0,
#      'subtype': 'facebookJumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-facebookJumbo.jpg',
#      'height': 550,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'facebookJumbo',
#      'crop_name': 'facebookJumbo'},
#     {'rank': 0,
#      'subtype': 'videoFifteenBySeven1305',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoFifteenBySeven1305.jpg',
#      'height': 609,
#      'width': 1305,
#      'legacy': {},
#      'subType': 'videoFifteenBySeven1305',
#      'crop_name': 'videoFifteenBySeven1305'},
#     {'rank': 0,
#      'subtype': 'videoFifteenBySeven2610',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoFifteenBySeven2610.jpg',
#      'height': 1218,
#      'width': 2610,
#      'legacy': {},
#      'subType': 'videoFifteenBySeven2610',
#      'crop_name': 'videoFifteenBySeven2610'},
#     {'rank': 0,
#      'subtype': 'miniMoth',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-miniMoth.jpg',
#      'height': 70,
#      'width': 151,
#      'legacy': {},
#      'subType': 'miniMoth',
#      'crop_name': 'miniMoth'},
#     {'rank': 0,
#      'subtype': 'windowsTile336H',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-windowsTile336H.jpg',
#      'height': 336,
#      'width': 694,
#      'legacy': {},
#      'subType': 'windowsTile336H',
#      'crop_name': 'windowsTile336H'},
#     {'rank': 0,
#      'subtype': 'verticalTwoByThree735',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-verticalTwoByThree735.jpg',
#      'height': 1102,
#      'width': 735,
#      'legacy': {},
#      'subType': 'verticalTwoByThree735',
#      'crop_name': 'verticalTwoByThree735'},
#     {'rank': 0,
#      'subtype': 'xlarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleLarge.jpg',
#      'height': 400,
#      'width': 600,
#      'legacy': {'xlarge': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleLarge.jpg',
#       'xlargewidth': 600,
#       'xlargeheight': 400},
#      'subType': 'xlarge',
#      'crop_name': 'articleLarge'},
#     {'rank': 0,
#      'subtype': 'blog480',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog480.jpg',
#      'height': 320,
#      'width': 480,
#      'legacy': {},
#      'subType': 'blog480',
#      'crop_name': 'blog480'},
#     {'rank': 0,
#      'subtype': 'blog427',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog427.jpg',
#      'height': 285,
#      'width': 427,
#      'legacy': {},
#      'subType': 'blog427',
#      'crop_name': 'blog427'},
#     {'rank': 0,
#      'subtype': 'tmagArticle',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-tmagArticle.jpg',
#      'height': 395,
#      'width': 592,
#      'legacy': {},
#      'subType': 'tmagArticle',
#      'crop_name': 'tmagArticle'},
#     {'rank': 0,
#      'subtype': 'jumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-jumbo.jpg',
#      'height': 683,
#      'width': 1024,
#      'legacy': {},
#      'subType': 'jumbo',
#      'crop_name': 'jumbo'},
#     {'rank': 0,
#      'subtype': 'blog225',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog225.jpg',
#      'height': 150,
#      'width': 225,
#      'legacy': {},
#      'subType': 'blog225',
#      'crop_name': 'blog225'},
#     {'rank': 0,
#      'subtype': 'master675',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master675.jpg',
#      'height': 450,
#      'width': 675,
#      'legacy': {},
#      'subType': 'master675',
#      'crop_name': 'master675'},
#     {'rank': 0,
#      'subtype': 'master180',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master180.jpg',
#      'height': 120,
#      'width': 180,
#      'legacy': {},
#      'subType': 'master180',
#      'crop_name': 'master180'},
#     {'rank': 0,
#      'subtype': 'master768',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master768.jpg',
#      'height': 512,
#      'width': 768,
#      'legacy': {},
#      'subType': 'master768',
#      'crop_name': 'master768'},
#     {'rank': 0,
#      'subtype': 'popup',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-popup.jpg',
#      'height': 433,
#      'width': 650,
#      'legacy': {},
#      'subType': 'popup',
#      'crop_name': 'popup'},
#     {'rank': 0,
#      'subtype': 'blog533',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog533.jpg',
#      'height': 355,
#      'width': 533,
#      'legacy': {},
#      'subType': 'blog533',
#      'crop_name': 'blog533'},
#     {'rank': 0,
#      'subtype': 'tmagSF',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-tmagSF.jpg',
#      'height': 241,
#      'width': 362,
#      'legacy': {},
#      'subType': 'tmagSF',
#      'crop_name': 'tmagSF'},
#     {'rank': 0,
#      'subtype': 'slide',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-slide.jpg',
#      'height': 400,
#      'width': 600,
#      'legacy': {},
#      'subType': 'slide',
#      'crop_name': 'slide'},
#     {'rank': 0,
#      'subtype': 'superJumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-superJumbo.jpg',
#      'height': 1365,
#      'width': 2048,
#      'legacy': {},
#      'subType': 'superJumbo',
#      'crop_name': 'superJumbo'},
#     {'rank': 0,
#      'subtype': 'master1050',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master1050.jpg',
#      'height': 700,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'master1050',
#      'crop_name': 'master1050'},
#     {'rank': 0,
#      'subtype': 'master495',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master495.jpg',
#      'height': 330,
#      'width': 495,
#      'legacy': {},
#      'subType': 'master495',
#      'crop_name': 'master495'},
#     {'rank': 0,
#      'subtype': 'master315',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master315.jpg',
#      'height': 210,
#      'width': 315,
#      'legacy': {},
#      'subType': 'master315',
#      'crop_name': 'master315'},
#     {'rank': 0,
#      'subtype': 'square320',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-square320.jpg',
#      'height': 320,
#      'width': 320,
#      'legacy': {},
#      'subType': 'square320',
#      'crop_name': 'square320'},
#     {'rank': 0,
#      'subtype': 'filmstrip',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-filmstrip.jpg',
#      'height': 190,
#      'width': 190,
#      'legacy': {},
#      'subType': 'filmstrip',
#      'crop_name': 'filmstrip'},
#     {'rank': 0,
#      'subtype': 'square640',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-square640.jpg',
#      'height': 640,
#      'width': 640,
#      'legacy': {},
#      'subType': 'square640',
#      'crop_name': 'square640'},
#     {'rank': 0,
#      'subtype': 'moth',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-moth.jpg',
#      'height': 151,
#      'width': 151,
#      'legacy': {},
#      'subType': 'moth',
#      'crop_name': 'moth'},
#     {'rank': 0,
#      'subtype': 'mediumSquare149',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumSquare149.jpg',
#      'height': 149,
#      'width': 149,
#      'legacy': {},
#      'subType': 'mediumSquare149',
#      'crop_name': 'mediumSquare149'},
#     {'rank': 0,
#      'subtype': 'articleInline',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleInline.jpg',
#      'height': 127,
#      'width': 190,
#      'legacy': {},
#      'subType': 'articleInline',
#      'crop_name': 'articleInline'},
#     {'rank': 0,
#      'subtype': 'hpSmall',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-hpSmall.jpg',
#      'height': 109,
#      'width': 163,
#      'legacy': {},
#      'subType': 'hpSmall',
#      'crop_name': 'hpSmall'},
#     {'rank': 0,
#      'subtype': 'blogSmallInline',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blogSmallInline.jpg',
#      'height': 101,
#      'width': 151,
#      'legacy': {},
#      'subType': 'blogSmallInline',
#      'crop_name': 'blogSmallInline'},
#     {'rank': 0,
#      'subtype': 'mediumFlexible177',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumFlexible177.jpg',
#      'height': 118,
#      'width': 177,
#      'legacy': {},
#      'subType': 'mediumFlexible177',
#      'crop_name': 'mediumFlexible177'},
#     {'rank': 0,
#      'subtype': 'sfSpan',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-sfSpan.jpg',
#      'height': 263,
#      'width': 395,
#      'legacy': {},
#      'subType': 'sfSpan',
#      'crop_name': 'sfSpan'},
#     {'rank': 0,
#      'subtype': 'largeHorizontalJumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeHorizontalJumbo.jpg',
#      'height': 683,
#      'width': 1024,
#      'legacy': {},
#      'subType': 'largeHorizontalJumbo',
#      'crop_name': 'largeHorizontalJumbo'},
#     {'rank': 0,
#      'subtype': 'largeHorizontal375',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeHorizontal375.jpg',
#      'height': 250,
#      'width': 375,
#      'legacy': {},
#      'subType': 'largeHorizontal375',
#      'crop_name': 'largeHorizontal375'},
#     {'rank': 0,
#      'subtype': 'hpLarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-hpLarge.jpg',
#      'height': 287,
#      'width': 511,
#      'legacy': {},
#      'subType': 'hpLarge',
#      'crop_name': 'hpLarge'},
#     {'rank': 0,
#      'subtype': 'largeWidescreen573',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeWidescreen573.jpg',
#      'height': 322,
#      'width': 573,
#      'legacy': {},
#      'subType': 'largeWidescreen573',
#      'crop_name': 'largeWidescreen573'},
#     {'rank': 0,
#      'subtype': 'largeWidescreen1050',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeWidescreen1050.jpg',
#      'height': 590,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'largeWidescreen1050',
#      'crop_name': 'largeWidescreen1050'},
#     {'rank': 0,
#      'subtype': 'videoSmall',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSmall.jpg',
#      'height': 281,
#      'width': 500,
#      'legacy': {},
#      'subType': 'videoSmall',
#      'crop_name': 'videoSmall'},
#     {'rank': 0,
#      'subtype': 'videoHpMedium',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoHpMedium.jpg',
#      'height': 211,
#      'width': 375,
#      'legacy': {},
#      'subType': 'videoHpMedium',
#      'crop_name': 'videoHpMedium'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine600',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine600.jpg',
#      'height': 338,
#      'width': 600,
#      'legacy': {},
#      'subType': 'videoSixteenByNine600',
#      'crop_name': 'videoSixteenByNine600'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine540',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine540.jpg',
#      'height': 304,
#      'width': 540,
#      'legacy': {},
#      'subType': 'videoSixteenByNine540',
#      'crop_name': 'videoSixteenByNine540'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine495',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine495.jpg',
#      'height': 278,
#      'width': 495,
#      'legacy': {},
#      'subType': 'videoSixteenByNine495',
#      'crop_name': 'videoSixteenByNine495'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine390',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine390.jpg',
#      'height': 219,
#      'width': 390,
#      'legacy': {},
#      'subType': 'videoSixteenByNine390',
#      'crop_name': 'videoSixteenByNine390'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine480',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine480.jpg',
#      'height': 270,
#      'width': 480,
#      'legacy': {},
#      'subType': 'videoSixteenByNine480',
#      'crop_name': 'videoSixteenByNine480'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine310',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine310.jpg',
#      'height': 174,
#      'width': 310,
#      'legacy': {},
#      'subType': 'videoSixteenByNine310',
#      'crop_name': 'videoSixteenByNine310'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine225',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine225.jpg',
#      'height': 126,
#      'width': 225,
#      'legacy': {},
#      'subType': 'videoSixteenByNine225',
#      'crop_name': 'videoSixteenByNine225'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine96',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine96.jpg',
#      'height': 54,
#      'width': 96,
#      'legacy': {},
#      'subType': 'videoSixteenByNine96',
#      'crop_name': 'videoSixteenByNine96'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine768',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine768.jpg',
#      'height': 432,
#      'width': 768,
#      'legacy': {},
#      'subType': 'videoSixteenByNine768',
#      'crop_name': 'videoSixteenByNine768'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine150',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine150.jpg',
#      'height': 84,
#      'width': 150,
#      'legacy': {},
#      'subType': 'videoSixteenByNine150',
#      'crop_name': 'videoSixteenByNine150'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine1050',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine1050.jpg',
#      'height': 591,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'videoSixteenByNine1050',
#      'crop_name': 'videoSixteenByNine1050'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine3000',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine3000.jpg',
#      'height': 1687,
#      'width': 3000,
#      'legacy': {},
#      'subType': 'videoSixteenByNine3000',
#      'crop_name': 'videoSixteenByNine3000'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNineJumbo1600',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNineJumbo1600.jpg',
#      'height': 900,
#      'width': 1600,
#      'legacy': {},
#      'subType': 'videoSixteenByNineJumbo1600',
#      'crop_name': 'videoSixteenByNineJumbo1600'},
#     {'rank': 0,
#      'subtype': 'thumbnail',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbStandard.jpg',
#      'height': 75,
#      'width': 75,
#      'legacy': {'thumbnail': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbStandard.jpg',
#       'thumbnailwidth': 75,
#       'thumbnailheight': 75},
#      'subType': 'thumbnail',
#      'crop_name': 'thumbStandard'},
#     {'rank': 0,
#      'subtype': 'thumbLarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbLarge.jpg',
#      'height': 150,
#      'width': 150,
#      'legacy': {},
#      'subType': 'thumbLarge',
#      'crop_name': 'thumbLarge'},
#     {'rank': 0,
#      'subtype': 'smallSquare252',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-smallSquare252.jpg',
#      'height': 252,
#      'width': 252,
#      'legacy': {},
#      'subType': 'smallSquare252',
#      'crop_name': 'smallSquare252'},
#     {'rank': 0,
#      'subtype': 'blogSmallThumb',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blogSmallThumb.jpg',
#      'height': 50,
#      'width': 50,
#      'legacy': {},
#      'subType': 'blogSmallThumb',
#      'crop_name': 'blogSmallThumb'},
#     {'rank': 0,
#      'subtype': 'smallSquare168',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-smallSquare168.jpg',
#      'height': 168,
#      'width': 168,
#      'legacy': {},
#      'subType': 'smallSquare168',
#      'crop_name': 'smallSquare168'}],
#    'headline': {'main': 'In a Brooklyn Basement, Jazz With a Russian Accent',
#     'kicker': None,
#     'content_kicker': None,
#     'print_headline': 'In a Brooklyn Basement, Jazz With a Russian Accent',
#     'name': None,
#     'seo': None,
#     'sub': None},
#    'keywords': [{'name': 'subject',
#      'value': 'Russian-Americans',
#      'rank': 2,
#      'major': 'N'},
#     {'name': 'glocations',
#      'value': 'USSR (Former Soviet Union)',
#      'rank': 3,
#      'major': 'N'},
#     {'name': 'subject', 'value': 'Music', 'rank': 4, 'major': 'N'},
#     {'name': 'glocations',
#      'value': 'Brighton Beach (Brooklyn, NY)',
#      'rank': 5,
#      'major': 'N'},
#     {'name': 'subject', 'value': 'Jazz', 'rank': 6, 'major': 'N'}],
#    'pub_date': '2016-05-16T14:56:32+0000',
#    'document_type': 'article',
#    'news_desk': 'Metro',
#    'section_name': 'New York',
#    'byline': {'original': 'By Corey Kilgannon',
#     'person': [{'firstname': 'Corey',
#       'middlename': None,
#       'lastname': 'Kilgannon',
#       'qualifier': None,
#       'title': None,
#       'role': 'reported',
#       'organization': '',
#       'rank': 1}],
#     'organization': None},
#    'type_of_material': 'News',
#    '_id': 'nyt://article/a7939e5d-f0ec-5b85-8375-95c0e24fe674',
#    'word_count': 1157,
#    'uri': 'nyt://article/a7939e5d-f0ec-5b85-8375-95c0e24fe674'},
#   {'abstract': 'Tom Manuel, a trumpeter, has founded a new exhibition, preservation and performance space housing his collection of at least 10,000 pieces of memorabilia.',
#    'web_url': 'https://www.nytimes.com/2016/05/22/nyregion/jazz-loft-housing-a-trove-of-memorabilia-opens-in-stony-brook.html',
#    'snippet': 'Tom Manuel, a trumpeter, has founded a new exhibition, preservation and performance space housing his collection of at least 10,000 pieces of memorabilia.',
#    'lead_paragraph': 'As a teenage trumpeter who loved jazz, Tom Manuel would visit the Dunton Inn, a local spot in East Patchogue where a group of old-timers — some of whom had played alongside Tommy Dorsey, Harry James and Louis Armstrong — would let the untried kid from Lake Ronkonkoma sit in during weekly jam sessions.',
#    'print_section': 'LI',
#    'print_page': '9',
#    'source': 'The New York Times',
#    'multimedia': [{'rank': 0,
#      'subtype': 'watch308',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-watch308.jpg',
#      'height': 348,
#      'width': 312,
#      'legacy': {},
#      'subType': 'watch308',
#      'crop_name': 'watch308'},
#     {'rank': 0,
#      'subtype': 'watch268',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-watch268.jpg',
#      'height': 303,
#      'width': 272,
#      'legacy': {},
#      'subType': 'watch268',
#      'crop_name': 'watch268'},
#     {'rank': 0,
#      'subtype': 'wide',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-thumbWide.jpg',
#      'height': 126,
#      'width': 190,
#      'legacy': {'widewidth': 190,
#       'wideheight': 126,
#       'wide': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-thumbWide.jpg'},
#      'subType': 'wide',
#      'crop_name': 'thumbWide'},
#     {'rank': 0,
#      'subtype': 'videoThumb',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoThumb.jpg',
#      'height': 50,
#      'width': 75,
#      'legacy': {},
#      'subType': 'videoThumb',
#      'crop_name': 'videoThumb'},
#     {'rank': 0,
#      'subtype': 'videoLarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoLarge.jpg',
#      'height': 507,
#      'width': 768,
#      'legacy': {},
#      'subType': 'videoLarge',
#      'crop_name': 'videoLarge'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo210',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo210.jpg',
#      'height': 140,
#      'width': 210,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo210',
#      'crop_name': 'mediumThreeByTwo210'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo225',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo225.jpg',
#      'height': 150,
#      'width': 225,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo225',
#      'crop_name': 'mediumThreeByTwo225'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo440',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo440.jpg',
#      'height': 293,
#      'width': 440,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo440',
#      'crop_name': 'mediumThreeByTwo440'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo252',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo252.jpg',
#      'height': 168,
#      'width': 252,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo252',
#      'crop_name': 'mediumThreeByTwo252'},
#     {'rank': 0,
#      'subtype': 'mediumThreeByTwo378',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo378.jpg',
#      'height': 252,
#      'width': 378,
#      'legacy': {},
#      'subType': 'mediumThreeByTwo378',
#      'crop_name': 'mediumThreeByTwo378'},
#     {'rank': 0,
#      'subtype': 'facebookJumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-facebookJumbo.jpg',
#      'height': 550,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'facebookJumbo',
#      'crop_name': 'facebookJumbo'},
#     {'rank': 0,
#      'subtype': 'videoFifteenBySeven1305',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoFifteenBySeven1305.jpg',
#      'height': 609,
#      'width': 1305,
#      'legacy': {},
#      'subType': 'videoFifteenBySeven1305',
#      'crop_name': 'videoFifteenBySeven1305'},
#     {'rank': 0,
#      'subtype': 'videoFifteenBySeven2610',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoFifteenBySeven2610.jpg',
#      'height': 1218,
#      'width': 2610,
#      'legacy': {},
#      'subType': 'videoFifteenBySeven2610',
#      'crop_name': 'videoFifteenBySeven2610'},
#     {'rank': 0,
#      'subtype': 'miniMoth',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-miniMoth.jpg',
#      'height': 70,
#      'width': 151,
#      'legacy': {},
#      'subType': 'miniMoth',
#      'crop_name': 'miniMoth'},
#     {'rank': 0,
#      'subtype': 'windowsTile336H',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-windowsTile336H.jpg',
#      'height': 336,
#      'width': 694,
#      'legacy': {},
#      'subType': 'windowsTile336H',
#      'crop_name': 'windowsTile336H'},
#     {'rank': 0,
#      'subtype': 'verticalTwoByThree735',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-verticalTwoByThree735.jpg',
#      'height': 1103,
#      'width': 735,
#      'legacy': {},
#      'subType': 'verticalTwoByThree735',
#      'crop_name': 'verticalTwoByThree735'},
#     {'rank': 0,
#      'subtype': 'xlarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleLarge.jpg',
#      'height': 400,
#      'width': 600,
#      'legacy': {'xlarge': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleLarge.jpg',
#       'xlargewidth': 600,
#       'xlargeheight': 400},
#      'subType': 'xlarge',
#      'crop_name': 'articleLarge'},
#     {'rank': 0,
#      'subtype': 'blog480',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog480.jpg',
#      'height': 320,
#      'width': 480,
#      'legacy': {},
#      'subType': 'blog480',
#      'crop_name': 'blog480'},
#     {'rank': 0,
#      'subtype': 'blog427',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog427.jpg',
#      'height': 285,
#      'width': 427,
#      'legacy': {},
#      'subType': 'blog427',
#      'crop_name': 'blog427'},
#     {'rank': 0,
#      'subtype': 'tmagArticle',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-tmagArticle.jpg',
#      'height': 395,
#      'width': 592,
#      'legacy': {},
#      'subType': 'tmagArticle',
#      'crop_name': 'tmagArticle'},
#     {'rank': 0,
#      'subtype': 'jumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-jumbo.jpg',
#      'height': 683,
#      'width': 1024,
#      'legacy': {},
#      'subType': 'jumbo',
#      'crop_name': 'jumbo'},
#     {'rank': 0,
#      'subtype': 'blog225',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog225.jpg',
#      'height': 150,
#      'width': 225,
#      'legacy': {},
#      'subType': 'blog225',
#      'crop_name': 'blog225'},
#     {'rank': 0,
#      'subtype': 'master675',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master675.jpg',
#      'height': 450,
#      'width': 675,
#      'legacy': {},
#      'subType': 'master675',
#      'crop_name': 'master675'},
#     {'rank': 0,
#      'subtype': 'master180',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master180.jpg',
#      'height': 120,
#      'width': 180,
#      'legacy': {},
#      'subType': 'master180',
#      'crop_name': 'master180'},
#     {'rank': 0,
#      'subtype': 'master768',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master768.jpg',
#      'height': 512,
#      'width': 768,
#      'legacy': {},
#      'subType': 'master768',
#      'crop_name': 'master768'},
#     {'rank': 0,
#      'subtype': 'popup',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-popup.jpg',
#      'height': 433,
#      'width': 650,
#      'legacy': {},
#      'subType': 'popup',
#      'crop_name': 'popup'},
#     {'rank': 0,
#      'subtype': 'blog533',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog533.jpg',
#      'height': 355,
#      'width': 533,
#      'legacy': {},
#      'subType': 'blog533',
#      'crop_name': 'blog533'},
#     {'rank': 0,
#      'subtype': 'tmagSF',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-tmagSF.jpg',
#      'height': 241,
#      'width': 362,
#      'legacy': {},
#      'subType': 'tmagSF',
#      'crop_name': 'tmagSF'},
#     {'rank': 0,
#      'subtype': 'slide',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-slide.jpg',
#      'height': 400,
#      'width': 600,
#      'legacy': {},
#      'subType': 'slide',
#      'crop_name': 'slide'},
#     {'rank': 0,
#      'subtype': 'superJumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-superJumbo.jpg',
#      'height': 1365,
#      'width': 2048,
#      'legacy': {},
#      'subType': 'superJumbo',
#      'crop_name': 'superJumbo'},
#     {'rank': 0,
#      'subtype': 'master1050',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master1050.jpg',
#      'height': 700,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'master1050',
#      'crop_name': 'master1050'},
#     {'rank': 0,
#      'subtype': 'master495',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master495.jpg',
#      'height': 330,
#      'width': 495,
#      'legacy': {},
#      'subType': 'master495',
#      'crop_name': 'master495'},
#     {'rank': 0,
#      'subtype': 'master315',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master315.jpg',
#      'height': 210,
#      'width': 315,
#      'legacy': {},
#      'subType': 'master315',
#      'crop_name': 'master315'},
#     {'rank': 0,
#      'subtype': 'square320',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-square320.jpg',
#      'height': 320,
#      'width': 320,
#      'legacy': {},
#      'subType': 'square320',
#      'crop_name': 'square320'},
#     {'rank': 0,
#      'subtype': 'filmstrip',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-filmstrip.jpg',
#      'height': 190,
#      'width': 190,
#      'legacy': {},
#      'subType': 'filmstrip',
#      'crop_name': 'filmstrip'},
#     {'rank': 0,
#      'subtype': 'square640',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-square640.jpg',
#      'height': 640,
#      'width': 640,
#      'legacy': {},
#      'subType': 'square640',
#      'crop_name': 'square640'},
#     {'rank': 0,
#      'subtype': 'moth',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-moth.jpg',
#      'height': 151,
#      'width': 151,
#      'legacy': {},
#      'subType': 'moth',
#      'crop_name': 'moth'},
#     {'rank': 0,
#      'subtype': 'mediumSquare149',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumSquare149.jpg',
#      'height': 149,
#      'width': 149,
#      'legacy': {},
#      'subType': 'mediumSquare149',
#      'crop_name': 'mediumSquare149'},
#     {'rank': 0,
#      'subtype': 'articleInline',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleInline.jpg',
#      'height': 127,
#      'width': 190,
#      'legacy': {},
#      'subType': 'articleInline',
#      'crop_name': 'articleInline'},
#     {'rank': 0,
#      'subtype': 'hpSmall',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-hpSmall.jpg',
#      'height': 109,
#      'width': 163,
#      'legacy': {},
#      'subType': 'hpSmall',
#      'crop_name': 'hpSmall'},
#     {'rank': 0,
#      'subtype': 'blogSmallInline',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blogSmallInline.jpg',
#      'height': 101,
#      'width': 151,
#      'legacy': {},
#      'subType': 'blogSmallInline',
#      'crop_name': 'blogSmallInline'},
#     {'rank': 0,
#      'subtype': 'mediumFlexible177',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumFlexible177.jpg',
#      'height': 118,
#      'width': 177,
#      'legacy': {},
#      'subType': 'mediumFlexible177',
#      'crop_name': 'mediumFlexible177'},
#     {'rank': 0,
#      'subtype': 'sfSpan',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-sfSpan.jpg',
#      'height': 263,
#      'width': 395,
#      'legacy': {},
#      'subType': 'sfSpan',
#      'crop_name': 'sfSpan'},
#     {'rank': 0,
#      'subtype': 'largeHorizontalJumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeHorizontalJumbo.jpg',
#      'height': 683,
#      'width': 1024,
#      'legacy': {},
#      'subType': 'largeHorizontalJumbo',
#      'crop_name': 'largeHorizontalJumbo'},
#     {'rank': 0,
#      'subtype': 'largeHorizontal375',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeHorizontal375.jpg',
#      'height': 250,
#      'width': 375,
#      'legacy': {},
#      'subType': 'largeHorizontal375',
#      'crop_name': 'largeHorizontal375'},
#     {'rank': 0,
#      'subtype': 'hpLarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-hpLarge.jpg',
#      'height': 287,
#      'width': 511,
#      'legacy': {},
#      'subType': 'hpLarge',
#      'crop_name': 'hpLarge'},
#     {'rank': 0,
#      'subtype': 'largeWidescreen573',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeWidescreen573.jpg',
#      'height': 322,
#      'width': 573,
#      'legacy': {},
#      'subType': 'largeWidescreen573',
#      'crop_name': 'largeWidescreen573'},
#     {'rank': 0,
#      'subtype': 'largeWidescreen1050',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeWidescreen1050.jpg',
#      'height': 590,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'largeWidescreen1050',
#      'crop_name': 'largeWidescreen1050'},
#     {'rank': 0,
#      'subtype': 'videoSmall',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSmall.jpg',
#      'height': 281,
#      'width': 500,
#      'legacy': {},
#      'subType': 'videoSmall',
#      'crop_name': 'videoSmall'},
#     {'rank': 0,
#      'subtype': 'videoHpMedium',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoHpMedium.jpg',
#      'height': 211,
#      'width': 375,
#      'legacy': {},
#      'subType': 'videoHpMedium',
#      'crop_name': 'videoHpMedium'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine600',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine600.jpg',
#      'height': 338,
#      'width': 600,
#      'legacy': {},
#      'subType': 'videoSixteenByNine600',
#      'crop_name': 'videoSixteenByNine600'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine540',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine540.jpg',
#      'height': 304,
#      'width': 540,
#      'legacy': {},
#      'subType': 'videoSixteenByNine540',
#      'crop_name': 'videoSixteenByNine540'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine495',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine495.jpg',
#      'height': 278,
#      'width': 495,
#      'legacy': {},
#      'subType': 'videoSixteenByNine495',
#      'crop_name': 'videoSixteenByNine495'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine390',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
# ...
#      'width': 675,
#      'legacy': {},
#      'subType': 'master675',
#      'crop_name': 'master675'},
#     {'rank': 0,
#      'subtype': 'master180',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master180.jpg',
#      'height': 120,
#      'width': 180,
#      'legacy': {},
#      'subType': 'master180',
#      'crop_name': 'master180'},
#     {'rank': 0,
#      'subtype': 'master768',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master768.jpg',
#      'height': 512,
#      'width': 768,
#      'legacy': {},
#      'subType': 'master768',
#      'crop_name': 'master768'},
#     {'rank': 0,
#      'subtype': 'popup',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-popup.jpg',
#      'height': 433,
#      'width': 650,
#      'legacy': {},
#      'subType': 'popup',
#      'crop_name': 'popup'},
#     {'rank': 0,
#      'subtype': 'blog533',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blog533.jpg',
#      'height': 355,
#      'width': 533,
#      'legacy': {},
#      'subType': 'blog533',
#      'crop_name': 'blog533'},
#     {'rank': 0,
#      'subtype': 'tmagSF',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-tmagSF.jpg',
#      'height': 241,
#      'width': 362,
#      'legacy': {},
#      'subType': 'tmagSF',
#      'crop_name': 'tmagSF'},
#     {'rank': 0,
#      'subtype': 'slide',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-slide.jpg',
#      'height': 400,
#      'width': 600,
#      'legacy': {},
#      'subType': 'slide',
#      'crop_name': 'slide'},
#     {'rank': 0,
#      'subtype': 'superJumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-superJumbo.jpg',
#      'height': 1365,
#      'width': 2048,
#      'legacy': {},
#      'subType': 'superJumbo',
#      'crop_name': 'superJumbo'},
#     {'rank': 0,
#      'subtype': 'master1050',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master1050.jpg',
#      'height': 700,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'master1050',
#      'crop_name': 'master1050'},
#     {'rank': 0,
#      'subtype': 'master495',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master495.jpg',
#      'height': 330,
#      'width': 495,
#      'legacy': {},
#      'subType': 'master495',
#      'crop_name': 'master495'},
#     {'rank': 0,
#      'subtype': 'master315',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master315.jpg',
#      'height': 210,
#      'width': 315,
#      'legacy': {},
#      'subType': 'master315',
#      'crop_name': 'master315'},
#     {'rank': 0,
#      'subtype': 'square320',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-square320.jpg',
#      'height': 320,
#      'width': 320,
#      'legacy': {},
#      'subType': 'square320',
#      'crop_name': 'square320'},
#     {'rank': 0,
#      'subtype': 'filmstrip',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-filmstrip.jpg',
#      'height': 190,
#      'width': 190,
#      'legacy': {},
#      'subType': 'filmstrip',
#      'crop_name': 'filmstrip'},
#     {'rank': 0,
#      'subtype': 'square640',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-square640.jpg',
#      'height': 640,
#      'width': 640,
#      'legacy': {},
#      'subType': 'square640',
#      'crop_name': 'square640'},
#     {'rank': 0,
#      'subtype': 'moth',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-moth.jpg',
#      'height': 151,
#      'width': 151,
#      'legacy': {},
#      'subType': 'moth',
#      'crop_name': 'moth'},
#     {'rank': 0,
#      'subtype': 'mediumSquare149',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-mediumSquare149.jpg',
#      'height': 149,
#      'width': 149,
#      'legacy': {},
#      'subType': 'mediumSquare149',
#      'crop_name': 'mediumSquare149'},
#     {'rank': 0,
#      'subtype': 'articleInline',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-articleInline.jpg',
#      'height': 127,
#      'width': 190,
#      'legacy': {},
#      'subType': 'articleInline',
#      'crop_name': 'articleInline'},
#     {'rank': 0,
#      'subtype': 'hpSmall',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-hpSmall.jpg',
#      'height': 109,
#      'width': 163,
#      'legacy': {},
#      'subType': 'hpSmall',
#      'crop_name': 'hpSmall'},
#     {'rank': 0,
#      'subtype': 'blogSmallInline',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blogSmallInline.jpg',
#      'height': 101,
#      'width': 151,
#      'legacy': {},
#      'subType': 'blogSmallInline',
#      'crop_name': 'blogSmallInline'},
#     {'rank': 0,
#      'subtype': 'mediumFlexible177',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-mediumFlexible177.jpg',
#      'height': 118,
#      'width': 177,
#      'legacy': {},
#      'subType': 'mediumFlexible177',
#      'crop_name': 'mediumFlexible177'},
#     {'rank': 0,
#      'subtype': 'sfSpan',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-sfSpan.jpg',
#      'height': 263,
#      'width': 395,
#      'legacy': {},
#      'subType': 'sfSpan',
#      'crop_name': 'sfSpan'},
#     {'rank': 0,
#      'subtype': 'largeHorizontalJumbo',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeHorizontalJumbo.jpg',
#      'height': 683,
#      'width': 1024,
#      'legacy': {},
#      'subType': 'largeHorizontalJumbo',
#      'crop_name': 'largeHorizontalJumbo'},
#     {'rank': 0,
#      'subtype': 'largeHorizontal375',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeHorizontal375.jpg',
#      'height': 250,
#      'width': 375,
#      'legacy': {},
#      'subType': 'largeHorizontal375',
#      'crop_name': 'largeHorizontal375'},
#     {'rank': 0,
#      'subtype': 'hpLarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-hpLarge.jpg',
#      'height': 287,
#      'width': 511,
#      'legacy': {},
#      'subType': 'hpLarge',
#      'crop_name': 'hpLarge'},
#     {'rank': 0,
#      'subtype': 'largeWidescreen573',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeWidescreen573.jpg',
#      'height': 322,
#      'width': 573,
#      'legacy': {},
#      'subType': 'largeWidescreen573',
#      'crop_name': 'largeWidescreen573'},
#     {'rank': 0,
#      'subtype': 'largeWidescreen1050',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeWidescreen1050.jpg',
#      'height': 591,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'largeWidescreen1050',
#      'crop_name': 'largeWidescreen1050'},
#     {'rank': 0,
#      'subtype': 'videoSmall',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSmall.jpg',
#      'height': 281,
#      'width': 500,
#      'legacy': {},
#      'subType': 'videoSmall',
#      'crop_name': 'videoSmall'},
#     {'rank': 0,
#      'subtype': 'videoHpMedium',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoHpMedium.jpg',
#      'height': 211,
#      'width': 375,
#      'legacy': {},
#      'subType': 'videoHpMedium',
#      'crop_name': 'videoHpMedium'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine600',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine600.jpg',
#      'height': 338,
#      'width': 600,
#      'legacy': {},
#      'subType': 'videoSixteenByNine600',
#      'crop_name': 'videoSixteenByNine600'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine540',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine540.jpg',
#      'height': 304,
#      'width': 540,
#      'legacy': {},
#      'subType': 'videoSixteenByNine540',
#      'crop_name': 'videoSixteenByNine540'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine495',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine495.jpg',
#      'height': 278,
#      'width': 495,
#      'legacy': {},
#      'subType': 'videoSixteenByNine495',
#      'crop_name': 'videoSixteenByNine495'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine390',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine390.jpg',
#      'height': 219,
#      'width': 390,
#      'legacy': {},
#      'subType': 'videoSixteenByNine390',
#      'crop_name': 'videoSixteenByNine390'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine480',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine480.jpg',
#      'height': 270,
#      'width': 480,
#      'legacy': {},
#      'subType': 'videoSixteenByNine480',
#      'crop_name': 'videoSixteenByNine480'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine310',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine310.jpg',
#      'height': 174,
#      'width': 310,
#      'legacy': {},
#      'subType': 'videoSixteenByNine310',
#      'crop_name': 'videoSixteenByNine310'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine225',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine225.jpg',
#      'height': 126,
#      'width': 225,
#      'legacy': {},
#      'subType': 'videoSixteenByNine225',
#      'crop_name': 'videoSixteenByNine225'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine96',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine96.jpg',
#      'height': 54,
#      'width': 96,
#      'legacy': {},
#      'subType': 'videoSixteenByNine96',
#      'crop_name': 'videoSixteenByNine96'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine768',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine768.jpg',
#      'height': 432,
#      'width': 768,
#      'legacy': {},
#      'subType': 'videoSixteenByNine768',
#      'crop_name': 'videoSixteenByNine768'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine150',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine150.jpg',
#      'height': 84,
#      'width': 150,
#      'legacy': {},
#      'subType': 'videoSixteenByNine150',
#      'crop_name': 'videoSixteenByNine150'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNine1050',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine1050.jpg',
#      'height': 591,
#      'width': 1050,
#      'legacy': {},
#      'subType': 'videoSixteenByNine1050',
#      'crop_name': 'videoSixteenByNine1050'},
#     {'rank': 0,
#      'subtype': 'videoSixteenByNineJumbo1600',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNineJumbo1600.jpg',
#      'height': 900,
#      'width': 1600,
#      'legacy': {},
#      'subType': 'videoSixteenByNineJumbo1600',
#      'crop_name': 'videoSixteenByNineJumbo1600'},
#     {'rank': 0,
#      'subtype': 'thumbnail',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbStandard.jpg',
#      'height': 75,
#      'width': 75,
#      'legacy': {'thumbnail': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbStandard.jpg',
#       'thumbnailwidth': 75,
#       'thumbnailheight': 75},
#      'subType': 'thumbnail',
#      'crop_name': 'thumbStandard'},
#     {'rank': 0,
#      'subtype': 'thumbLarge',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbLarge.jpg',
#      'height': 150,
#      'width': 150,
#      'legacy': {},
#      'subType': 'thumbLarge',
#      'crop_name': 'thumbLarge'},
#     {'rank': 0,
#      'subtype': 'smallSquare252',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-smallSquare252.jpg',
#      'height': 252,
#      'width': 252,
#      'legacy': {},
#      'subType': 'smallSquare252',
#      'crop_name': 'smallSquare252'},
#     {'rank': 0,
#      'subtype': 'blogSmallThumb',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blogSmallThumb.jpg',
#      'height': 50,
#      'width': 50,
#      'legacy': {},
#      'subType': 'blogSmallThumb',
#      'crop_name': 'blogSmallThumb'},
#     {'rank': 0,
#      'subtype': 'smallSquare168',
#      'caption': None,
#      'credit': None,
#      'type': 'image',
#      'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-smallSquare168.jpg',
#      'height': 168,
#      'width': 168,
#      'legacy': {},
#      'subType': 'smallSquare168',
#      'crop_name': 'smallSquare168'}],
#    'headline': {'main': 'Review: Cecil Taylor’s Mysteries Don’t Resolve at the 88th Key',
#     'kicker': None,
#     'content_kicker': None,
#     'print_headline': 'A Pianist’s Mysteries  Do Not Resolve  at the 88th Key',
#     'name': None,
#     'seo': None,
#     'sub': None},
#    'keywords': [{'name': 'subject', 'value': 'Music', 'rank': 1, 'major': 'N'},
#     {'name': 'organizations',
#      'value': 'Whitney Museum of American Art',
#      'rank': 3,
#      'major': 'N'},
#     {'name': 'subject', 'value': 'Jazz', 'rank': 4, 'major': 'N'},
#     {'name': 'persons', 'value': 'Tanaka, Min', 'rank': 5, 'major': 'N'},
#     {'name': 'creative_works',
#      'value': 'Cecil Taylor: Open Plan (Exhibit)',
#      'rank': 6,
#      'major': 'N'},
#     {'name': 'persons', 'value': 'Taylor, Cecil', 'rank': 7, 'major': 'N'}],
#    'pub_date': '2016-04-15T20:57:11+0000',
#    'document_type': 'article',
#    'news_desk': 'Culture',
#    'section_name': 'Arts',
#    'subsection_name': 'Music',
#    'byline': {'original': 'By Ben Ratliff',
#     'person': [{'firstname': 'Ben',
#       'middlename': None,
#       'lastname': 'Ratliff',
#       'qualifier': None,
#       'title': None,
#       'role': 'reported',
#       'organization': '',
#       'rank': 1}],
#     'organization': None},
#    'type_of_material': 'Review',
#    '_id': 'nyt://article/20d00e40-9af0-59b5-bad5-2b9b0ef725e7',
#    'word_count': 797,
#    'uri': 'nyt://article/20d00e40-9af0-59b5-bad5-2b9b0ef725e7'}],
#  'meta': {'hits': 47, 'offset': 10, 'time': 22}}

# %% [markdown]
# It's a dictionary of dictionaries! (*Inception meme*). We'll need to parse this dictionary even further. Let's look at its keys.

# %%
data['response'].keys()
# Out:
# dict_keys(['docs', 'meta'])

# %%
#ah-ha! One step closer: we know there were 49 hits in our date range
data['response']['meta']
# Out:
# {'hits': 47, 'offset': 10, 'time': 22}

# %%
#But we can further explore deeper in the JSON structure
data_response = data['response']['docs']
data_response
# Out:
# [{'abstract': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#   'web_url': 'https://www.nytimes.com/2016/04/04/arts/music/review-wynton-marsaliss-spaces-a-kinetic-series-of-zoological-portraits.html',
#   'snippet': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#   'lead_paragraph': 'The kazoos cropped up in the 10th and final movement of “Spaces,” an episodic suite by Wynton Marsalis that had its world premiere at the Rose Theater on Friday. The Jazz at Lincoln Center Orchestra was swinging light and fast as it happened, bzz-bzz-bzz-bzz-bzz, in a busy rush. It was a cute and clever flourish, in a piece titled “Bees Bees Bees.” And it was also an act of evocation that reflected the larger theme of the suite.',
#   'print_section': 'C',
#   'print_page': '4',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Music', 'rank': 1, 'major': 'N'},
#    {'name': 'subject', 'value': 'Dancing', 'rank': 3, 'major': 'N'},
#    {'name': 'subject', 'value': 'Jazz', 'rank': 4, 'major': 'N'},
#    {'name': 'persons', 'value': 'Marsalis, Wynton', 'rank': 5, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'Spaces (Musical Work)',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Jazz at Lincoln Center',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Jazz at Lincoln Center Orchestra',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'organizations', 'value': 'Rose Theater', 'rank': 9, 'major': 'N'},
#    {'name': 'persons', 'value': 'Grimes, Jared', 'rank': 10, 'major': 'N'},
#    {'name': 'persons', 'value': 'Lil Buck', 'rank': 11, 'major': 'N'},
#    {'name': 'persons', 'value': 'Sneed, Damien', 'rank': 12, 'major': 'N'}],
#   'pub_date': '2016-04-03T22:54:49+0000',
#   'document_type': 'article',
#   'news_desk': 'Culture',
#   'section_name': 'Arts',
#   'subsection_name': 'Music',
#   'byline': {'original': 'By Nate Chinen',
#    'person': [{'firstname': 'Nate',
#      'middlename': None,
#      'lastname': 'Chinen',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Review',
#   '_id': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a',
#   'word_count': 423,
#   'uri': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a'},
#  {'abstract': 'Most members of a 20-piece band that plays regularly in Sheepshead Bay learned jazz clandestinely in Soviet-era Russia, where the authorities were suspicious of people interested in American culture.',
#   'web_url': 'https://www.nytimes.com/2016/05/17/nyregion/in-a-brooklyn-basement-jazz-with-a-russian-accent.html',
#   'snippet': 'Most members of a 20-piece band that plays regularly in Sheepshead Bay learned jazz clandestinely in Soviet-era Russia, where the authorities were suspicious of people interested in American culture.',
#   'lead_paragraph': 'In the 1960s and ’70s in Moscow, Nina Brodskaya was a singing star.',
#   'print_section': 'A',
#   'print_page': '18',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-verticalTwoByThree735.jpg',
#     'height': 1102,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog480.jpg',
#     'height': 320,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog427.jpg',
#     'height': 285,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-tmagArticle.jpg',
#     'height': 395,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-jumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-superJumbo.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-largeWidescreen1050.jpg',
#     'height': 590,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine3000',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNine3000.jpg',
#     'height': 1687,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'videoSixteenByNine3000',
#     'crop_name': 'videoSixteenByNine3000'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNineJumbo1600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-videoSixteenByNineJumbo1600.jpg',
#     'height': 900,
#     'width': 1600,
#     'legacy': {},
#     'subType': 'videoSixteenByNineJumbo1600',
#     'crop_name': 'videoSixteenByNineJumbo1600'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/17/nyregion/17RUSSIANBANDss-slide-CD6Y/17RUSSIANBANDss-slide-CD6Y-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'}],
#   'headline': {'main': 'In a Brooklyn Basement, Jazz With a Russian Accent',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'In a Brooklyn Basement, Jazz With a Russian Accent',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Russian-Americans',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'glocations',
#     'value': 'USSR (Former Soviet Union)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Music', 'rank': 4, 'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Brighton Beach (Brooklyn, NY)',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Jazz', 'rank': 6, 'major': 'N'}],
#   'pub_date': '2016-05-16T14:56:32+0000',
#   'document_type': 'article',
#   'news_desk': 'Metro',
#   'section_name': 'New York',
#   'byline': {'original': 'By Corey Kilgannon',
#    'person': [{'firstname': 'Corey',
#      'middlename': None,
#      'lastname': 'Kilgannon',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/a7939e5d-f0ec-5b85-8375-95c0e24fe674',
#   'word_count': 1157,
#   'uri': 'nyt://article/a7939e5d-f0ec-5b85-8375-95c0e24fe674'},
#  {'abstract': 'Tom Manuel, a trumpeter, has founded a new exhibition, preservation and performance space housing his collection of at least 10,000 pieces of memorabilia.',
#   'web_url': 'https://www.nytimes.com/2016/05/22/nyregion/jazz-loft-housing-a-trove-of-memorabilia-opens-in-stony-brook.html',
#   'snippet': 'Tom Manuel, a trumpeter, has founded a new exhibition, preservation and performance space housing his collection of at least 10,000 pieces of memorabilia.',
#   'lead_paragraph': 'As a teenage trumpeter who loved jazz, Tom Manuel would visit the Dunton Inn, a local spot in East Patchogue where a group of old-timers — some of whom had played alongside Tommy Dorsey, Harry James and Louis Armstrong — would let the untried kid from Lake Ronkonkoma sit in during weekly jam sessions.',
#   'print_section': 'LI',
#   'print_page': '9',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-verticalTwoByThree735.jpg',
#     'height': 1103,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog480.jpg',
#     'height': 320,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog427.jpg',
#     'height': 285,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-tmagArticle.jpg',
#     'height': 395,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-jumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-superJumbo.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-largeWidescreen1050.jpg',
#     'height': 590,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/05/22/nyregion/22ARTSLI1/22ARTSLI1-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
# ...
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-superJumbo.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNineJumbo1600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-videoSixteenByNineJumbo1600.jpg',
#     'height': 900,
#     'width': 1600,
#     'legacy': {},
#     'subType': 'videoSixteenByNineJumbo1600',
#     'crop_name': 'videoSixteenByNineJumbo1600'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/04/16/arts/16CECIL1SUB/16CECIL1SUB-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'}],
#   'headline': {'main': 'Review: Cecil Taylor’s Mysteries Don’t Resolve at the 88th Key',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'A Pianist’s Mysteries  Do Not Resolve  at the 88th Key',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject', 'value': 'Music', 'rank': 1, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Whitney Museum of American Art',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Jazz', 'rank': 4, 'major': 'N'},
#    {'name': 'persons', 'value': 'Tanaka, Min', 'rank': 5, 'major': 'N'},
#    {'name': 'creative_works',
#     'value': 'Cecil Taylor: Open Plan (Exhibit)',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Taylor, Cecil', 'rank': 7, 'major': 'N'}],
#   'pub_date': '2016-04-15T20:57:11+0000',
#   'document_type': 'article',
#   'news_desk': 'Culture',
#   'section_name': 'Arts',
#   'subsection_name': 'Music',
#   'byline': {'original': 'By Ben Ratliff',
#    'person': [{'firstname': 'Ben',
#      'middlename': None,
#      'lastname': 'Ratliff',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Review',
#   '_id': 'nyt://article/20d00e40-9af0-59b5-bad5-2b9b0ef725e7',
#   'word_count': 797,
#   'uri': 'nyt://article/20d00e40-9af0-59b5-bad5-2b9b0ef725e7'}]

# %% [markdown]
# Let's look at the first one:

# %%
type(data_response)
# Out:
# list

# %%
len(data_response)
# Out:
# 10

# %%
data_response[0]
# Out:
# {'abstract': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#  'web_url': 'https://www.nytimes.com/2016/04/04/arts/music/review-wynton-marsaliss-spaces-a-kinetic-series-of-zoological-portraits.html',
#  'snippet': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#  'lead_paragraph': 'The kazoos cropped up in the 10th and final movement of “Spaces,” an episodic suite by Wynton Marsalis that had its world premiere at the Rose Theater on Friday. The Jazz at Lincoln Center Orchestra was swinging light and fast as it happened, bzz-bzz-bzz-bzz-bzz, in a busy rush. It was a cute and clever flourish, in a piece titled “Bees Bees Bees.” And it was also an act of evocation that reflected the larger theme of the suite.',
#  'print_section': 'C',
#  'print_page': '4',
#  'source': 'The New York Times',
#  'multimedia': [],
#  'headline': {'main': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#   'kicker': None,
#   'content_kicker': None,
#   'print_headline': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'name': 'subject', 'value': 'Music', 'rank': 1, 'major': 'N'},
#   {'name': 'subject', 'value': 'Dancing', 'rank': 3, 'major': 'N'},
#   {'name': 'subject', 'value': 'Jazz', 'rank': 4, 'major': 'N'},
#   {'name': 'persons', 'value': 'Marsalis, Wynton', 'rank': 5, 'major': 'N'},
#   {'name': 'creative_works',
#    'value': 'Spaces (Musical Work)',
#    'rank': 6,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Jazz at Lincoln Center',
#    'rank': 7,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Jazz at Lincoln Center Orchestra',
#    'rank': 8,
#    'major': 'N'},
#   {'name': 'organizations', 'value': 'Rose Theater', 'rank': 9, 'major': 'N'},
#   {'name': 'persons', 'value': 'Grimes, Jared', 'rank': 10, 'major': 'N'},
#   {'name': 'persons', 'value': 'Lil Buck', 'rank': 11, 'major': 'N'},
#   {'name': 'persons', 'value': 'Sneed, Damien', 'rank': 12, 'major': 'N'}],
#  'pub_date': '2016-04-03T22:54:49+0000',
#  'document_type': 'article',
#  'news_desk': 'Culture',
#  'section_name': 'Arts',
#  'subsection_name': 'Music',
#  'byline': {'original': 'By Nate Chinen',
#   'person': [{'firstname': 'Nate',
#     'middlename': None,
#     'lastname': 'Chinen',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 1}],
#   'organization': None},
#  'type_of_material': 'Review',
#  '_id': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a',
#  'word_count': 423,
#  'uri': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a'}

# %%
#another dictionary!
type(data_response[0])
# Out:
# dict

# %%
(data_response[0])
# Out:
# {'abstract': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#  'web_url': 'https://www.nytimes.com/2016/04/04/arts/music/review-wynton-marsaliss-spaces-a-kinetic-series-of-zoological-portraits.html',
#  'snippet': 'In this premiere, the Jazz at Lincoln Center Orchestra moved from buzzing kazoos for bees to clucking reeds to an elephantine harrumph by clarinets and trombones.',
#  'lead_paragraph': 'The kazoos cropped up in the 10th and final movement of “Spaces,” an episodic suite by Wynton Marsalis that had its world premiere at the Rose Theater on Friday. The Jazz at Lincoln Center Orchestra was swinging light and fast as it happened, bzz-bzz-bzz-bzz-bzz, in a busy rush. It was a cute and clever flourish, in a piece titled “Bees Bees Bees.” And it was also an act of evocation that reflected the larger theme of the suite.',
#  'print_section': 'C',
#  'print_page': '4',
#  'source': 'The New York Times',
#  'multimedia': [],
#  'headline': {'main': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#   'kicker': None,
#   'content_kicker': None,
#   'print_headline': 'Review: Wynton Marsalis’s ‘Spaces,’ a Kinetic Series of Zoological Portraits',
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'name': 'subject', 'value': 'Music', 'rank': 1, 'major': 'N'},
#   {'name': 'subject', 'value': 'Dancing', 'rank': 3, 'major': 'N'},
#   {'name': 'subject', 'value': 'Jazz', 'rank': 4, 'major': 'N'},
#   {'name': 'persons', 'value': 'Marsalis, Wynton', 'rank': 5, 'major': 'N'},
#   {'name': 'creative_works',
#    'value': 'Spaces (Musical Work)',
#    'rank': 6,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Jazz at Lincoln Center',
#    'rank': 7,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Jazz at Lincoln Center Orchestra',
#    'rank': 8,
#    'major': 'N'},
#   {'name': 'organizations', 'value': 'Rose Theater', 'rank': 9, 'major': 'N'},
#   {'name': 'persons', 'value': 'Grimes, Jared', 'rank': 10, 'major': 'N'},
#   {'name': 'persons', 'value': 'Lil Buck', 'rank': 11, 'major': 'N'},
#   {'name': 'persons', 'value': 'Sneed, Damien', 'rank': 12, 'major': 'N'}],
#  'pub_date': '2016-04-03T22:54:49+0000',
#  'document_type': 'article',
#  'news_desk': 'Culture',
#  'section_name': 'Arts',
#  'subsection_name': 'Music',
#  'byline': {'original': 'By Nate Chinen',
#   'person': [{'firstname': 'Nate',
#     'middlename': None,
#     'lastname': 'Chinen',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 1}],
#   'organization': None},
#  'type_of_material': 'Review',
#  '_id': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a',
#  'word_count': 423,
#  'uri': 'nyt://article/a7caa009-ac11-5e44-9ee8-1e847fbac62a'}

# %%
data_response[0].keys()
# Out:
# dict_keys(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'print_section', 'print_page', 'source', 'multimedia', 'headline', 'keywords', 'pub_date', 'document_type', 'news_desk', 'section_name', 'subsection_name', 'byline', 'type_of_material', '_id', 'word_count', 'uri'])

# %%
data_response[0]['word_count']
# Out:
# 423

# %% [markdown]
# It's a list of dictionaries!

# %% [markdown]
# With a list of dictionaries, we can, of course, create a Pandas dataframe!
#
# ### Create a pandas dataframe called `df_all` from the list of dictionaries we created above.

# %%
df_all = pandas.DataFrame(data['response']['docs'])
df_all
# Out:
#                                             abstract  \
# 0  In this premiere, the Jazz at Lincoln Center O...
# 1  Most members of a 20-piece band that plays reg...
# 2  Tom Manuel, a trumpeter, has founded a new exh...
# 3  Michael Formanek and Ensemble Kolossus showcas...
# 4  It represents the conservative uptown wing of ...
# 5  “Collected Essays & Memoirs” gathers writing f...
# 6  The museum’s goal is to do public programming ...
# 7  A selection of the musician’s extensive photog...
# 8  Mr. Batiste gets up late, prays, meditates, lo...
# 9  Mr. Taylor’s music, poetry and more are the fo...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2016/04/04/arts/music/...
# 1  https://www.nytimes.com/2016/05/17/nyregion/in...
# 2  https://www.nytimes.com/2016/05/22/nyregion/ja...
# 3  https://www.nytimes.com/2016/03/25/arts/music/...
# 4  https://www.nytimes.com/2016/10/20/arts/music/...
# 5  https://www.nytimes.com/2016/10/21/books/revie...
# 6  https://www.nytimes.com/2016/03/31/arts/music/...
# 7  https://www.nytimes.com/2016/11/21/arts/design...
# 8  https://www.nytimes.com/2016/11/23/nyregion/jo...
# 9  https://www.nytimes.com/2016/04/16/arts/music/...
#
#                                              snippet  \
# 0  In this premiere, the Jazz at Lincoln Center O...
# 1  Most members of a 20-piece band that plays reg...
# 2  Tom Manuel, a trumpeter, has founded a new exh...
# 3  Michael Formanek and Ensemble Kolossus showcas...
# 4  It represents the conservative uptown wing of ...
# 5  “Collected Essays & Memoirs” gathers writing f...
# 6  The museum’s goal is to do public programming ...
# 7  A selection of the musician’s extensive photog...
# 8  Mr. Batiste gets up late, prays, meditates, lo...
# 9  Mr. Taylor’s music, poetry and more are the fo...
#
#                                       lead_paragraph print_section print_page  \
# 0  The kazoos cropped up in the 10th and final mo...             C          4
# 1  In the 1960s and ’70s in Moscow, Nina Brodskay...             A         18
# 2  As a teenage trumpeter who loved jazz, Tom Man...            LI          9
# 3  For a deceiving stretch of its first set at th...             C          3
# 4  Maureen McGovern was presented with the Mabel ...             C          6
# 5  “It is always open season on the truth,” the g...             C         25
# 6  The National Jazz Museum in Harlem has always ...             C          1
# 7  Elton John famously collects eccentric eyewear...             C          5
# 8  Between leading impromptu street parades, perf...            MB          2
# 9  First things first: The pianist Cecil Taylor, ...             C          3
#
#                source                                         multimedia  \
# 0  The New York Times                                                 []
# 1  The New York Times  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 2  The New York Times  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 3  The New York Times  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 4  The New York Times  [{'rank': 0, 'subtype': 'thumbnail', 'caption'...
# 5  The New York Times  [{'rank': 0, 'subtype': 'sfSpan', 'caption': N...
# 6  The New York Times  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 7  The New York Times  [{'rank': 0, 'subtype': 'videoSmall', 'caption...
# 8  The New York Times  [{'rank': 0, 'subtype': 'articleInline', 'capt...
# 9  The New York Times  [{'rank': 0, 'subtype': 'watch308', 'caption':...
#
#                                             headline  \
# 0  {'main': 'Review: Wynton Marsalis’s ‘Spaces,’ ...
# 1  {'main': 'In a Brooklyn Basement, Jazz With a ...
# 2  {'main': 'Jazz Loft, Housing a Trove of Memora...
# 3  {'main': 'Review: Delivering a Touch of Big Ba...
# 4  {'main': 'Review: New York Cabaret Convention ...
# 5  {'main': 'Review: Albert Murray’s Symphonic El...
# 6  {'main': 'The National Jazz Museum in Harlem F...
# 7  {'main': 'From Elton John, Photography’s Great...
# 8  {'main': 'How Jon Batiste, Bandleader on ‘Late...
# 9  {'main': 'Review: Cecil Taylor’s Mysteries Don...
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Music', 'rank':...
# 1  [{'name': 'subject', 'value': 'Russian-America...
# 2  [{'name': 'subject', 'value': 'Music', 'rank':...
# 3  [{'name': 'subject', 'value': 'Music', 'rank':...
# 4  [{'name': 'subject', 'value': 'Music', 'rank':...
# 5  [{'name': 'subject', 'value': 'Books and Liter...
# 6  [{'name': 'organizations', 'value': 'National ...
# 7  [{'name': 'subject', 'value': 'Art', 'rank': 1...
# 8  [{'name': 'organizations', 'value': 'National ...
# 9  [{'name': 'subject', 'value': 'Music', 'rank':...
#
#                    pub_date document_type     news_desk section_name  \
# 0  2016-04-03T22:54:49+0000       article       Culture         Arts
# 1  2016-05-16T14:56:32+0000       article         Metro     New York
# 2  2016-05-20T23:08:15+0000       article  Metropolitan     New York
# 3  2016-03-24T19:35:47+0000       article       Weekend         Arts
# 4  2016-10-19T21:54:35+0000       article       Culture         Arts
# 5  2016-10-20T20:26:14+0000       article       Weekend        Books
# 6  2016-03-30T21:21:24+0000       article       Culture         Arts
# 7  2016-11-21T14:34:35+0000       article       Culture         Arts
# 8  2016-11-24T00:43:46+0000       article  Metropolitan     New York
# 9  2016-04-15T20:57:11+0000       article       Culture         Arts
#
#   subsection_name                                             byline  \
# 0           Music  {'original': 'By Nate Chinen', 'person': [{'fi...
# 1             NaN  {'original': 'By Corey Kilgannon', 'person': [...
# 2             NaN  {'original': 'By Karin Lipson', 'person': [{'f...
# 3           Music  {'original': 'By Nate Chinen', 'person': [{'fi...
# 4           Music  {'original': 'By Stephen Holden', 'person': [{...
# 5             NaN  {'original': 'By Dwight Garner', 'person': [{'...
# 6           Music  {'original': 'By Nate Chinen', 'person': [{'fi...
# 7    Art & Design  {'original': 'By Farah Nayeri', 'person': [{'f...
# 8             NaN  {'original': 'By Shivani Vora', 'person': [{'f...
# 9           Music  {'original': 'By Ben Ratliff', 'person': [{'fi...
#
#   type_of_material                                                _id  \
# 0           Review  nyt://article/a7caa009-ac11-5e44-9ee8-1e847fba...
# 1             News  nyt://article/a7939e5d-f0ec-5b85-8375-95c0e24f...
# 2             News  nyt://article/1beae8ae-9ac4-509d-b508-ab8f9788...
# 3           Review  nyt://article/bdb1ee87-03b8-5170-90ac-1e2c770a...
# 4           Review  nyt://article/1628374e-cfff-51d2-940f-610ad6dc...
# 5           Review  nyt://article/2581551a-d710-56cc-8678-1be919e7...
# 6             News  nyt://article/d3a18215-8ef0-5357-8860-5e0ca4e7...
# 7             News  nyt://article/470350ff-c92a-5a98-a117-a3ed42a7...
# 8             News  nyt://article/047d945e-1bd3-5123-bd1b-3669b1c6...
# 9           Review  nyt://article/20d00e40-9af0-59b5-bad5-2b9b0ef7...
#
#    word_count                                                uri
# 0         423  nyt://article/a7caa009-ac11-5e44-9ee8-1e847fba...
# 1        1157  nyt://article/a7939e5d-f0ec-5b85-8375-95c0e24f...
# 2         785  nyt://article/1beae8ae-9ac4-509d-b508-ab8f9788...
# 3         514  nyt://article/bdb1ee87-03b8-5170-90ac-1e2c770a...
# 4         530  nyt://article/1628374e-cfff-51d2-940f-610ad6dc...
# 5         990  nyt://article/2581551a-d710-56cc-8678-1be919e7...
# 6         750  nyt://article/d3a18215-8ef0-5357-8860-5e0ca4e7...
# 7         762  nyt://article/470350ff-c92a-5a98-a117-a3ed42a7...
# 8         740  nyt://article/047d945e-1bd3-5123-bd1b-3669b1c6...
# 9         797  nyt://article/20d00e40-9af0-59b5-bad5-2b9b0ef7...

# %% [markdown]
# Note: the meta field does contain the total number of hits for the date range.
#
# The full response field, however, only contain the data from one page: only 10 documents.
#
# Think through how you might write a for-loop to collect all of them, if you're interested.

# %% [markdown]
# ## 3. Putting everything together to count the number of articles per year
#
# Let's write a for-loop to collect the number of hits per year for a search-term of your choice (I'm going to do Duke Elington). We will do so by creating a dictionary object to structure our data (e.g., {year: count, year: count}.
#
# Note: the API has limits on it, so don't go back to the beginning of time. Use a limited date range.
#
# We'll collect everything we did previously into one cell below, so that when you run the cell, it outputs the data, structured as you need it.
#
# **Reminder:** We don't want overload the server. Inside your for-loop, we will include a sleep line (I recommend 1-5 seconds):
#
# `time.sleep(5)`
#
# Do this whenever you use an API.
#
# Question: What year had the highest count for your search term?

# %%
#write the full code here, starting by assigning the base_url

key = "ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM" #put your key here

base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

start_root = "0101"
end_root = "1231"
q = ''
hits = {}

for date in range(2000, 2022):
    try:
        start_date = str(date)+start_root
        end_date = str(date)+end_root
        print(start_date)
        search_params = {"q": "Duke Ellington",
                     "api-key": key,
                    "begin_date": start_date,
                    "end_date": end_date}

        r = requests.get(base_url, params=search_params)
        response_text = r.text
        data = json.loads(response_text)
        print(r.url)
        num_hits = data['response']['meta']['hits']
        hits[date] = num_hits
        time.sleep(5)
    except:
        print(r.url)
        print("Oh no, something went wrong.")
hits

# %%
#write the full code here, starting by assigning the base_url

key = "ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM" #put your key here

base_url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

start_root = "0101"
end_root = "1231"
q = ''
hits_BH = {}

for date in range(2000, 2022):
    try:
        start_date = str(date)+start_root
        end_date = str(date)+end_root
        print(start_date)
        search_params = {"q": "Billie Holiday",
                     "api-key": key,
                    "begin_date": start_date,
                    "end_date": end_date}

        r = requests.get(base_url, params=search_params)
        response_text = r.text
        data = json.loads(response_text)
        print(r.url)
        num_hits_BH = data['response']['meta']['hits']
        hits_BH[date] = num_hits_BH
        time.sleep(5)
    except:
        print(r.url)
        print("Oh no, something went wrong.")
hits_BH
# Out:
# 20000101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20000101&end_date=20001231
# 20010101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20010101&end_date=20011231
# 20020101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20020101&end_date=20021231
# 20030101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20030101&end_date=20031231
# 20040101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20040101&end_date=20041231
# 20050101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20050101&end_date=20051231
# 20060101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20060101&end_date=20061231
# 20070101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20070101&end_date=20071231
# 20080101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20080101&end_date=20081231
# 20090101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20090101&end_date=20091231
# 20100101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20100101&end_date=20101231
# 20110101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20110101&end_date=20111231
# 20120101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20120101&end_date=20121231
# 20130101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20130101&end_date=20131231
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20130101&end_date=20131231
# Oh no, something went wrong.
# 20140101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20140101&end_date=20141231
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20140101&end_date=20141231
# Oh no, something went wrong.
# 20150101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20150101&end_date=20151231
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20150101&end_date=20151231
# Oh no, something went wrong.
# 20160101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20160101&end_date=20161231
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20160101&end_date=20161231
# Oh no, something went wrong.
# 20170101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20170101&end_date=20171231
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20170101&end_date=20171231
# Oh no, something went wrong.
# 20180101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20180101&end_date=20181231
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20180101&end_date=20181231
# Oh no, something went wrong.
# 20190101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20190101&end_date=20191231
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20190101&end_date=20191231
# Oh no, something went wrong.
# 20200101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20200101&end_date=20201231
# 20210101
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Billie+Holiday&api-key=ITjx9GXGGuyRSTGJGVCxHc130S1LOsyM&begin_date=20210101&end_date=20211231
# {2000: 91,
#  2001: 115,
#  2002: 77,
#  2003: 70,
#  2004: 52,
#  2005: 65,
#  2006: 122,
#  2007: 68,
#  2008: 63,
#  2009: 71,
#  2010: 61,
#  2011: 72,
#  2012: 34,
#  2020: 63,
#  2021: 101}

# %% [markdown]
# New skill: writing files!
#
# You just collected that data, and now you want to save it so you don't have to re-ping the NYTimes server next time you want to look at the data.
#
# We can write files, similar to how we read files.

# %%
#Caution with read and write flags!
#Don't confuse them! Please don't confuse them!

filename = '../data/nyt_output_ellington.json'
with open(filename, 'w') as outfile:
    json.dump(hits, outfile)

# %%
#Let's turn the hits object into a Pandas dataframe
df_hits = pandas.DataFrame(hits, index = ['hits'])
df_hits
# Out:
#       2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  ...  2011  \
# hits   179   145   151   132   137   106   171   101   115   134  ...    89
#
#       2012  2013  2014  2016  2017  2018  2019  2020  2021
# hits    67   119   150    47    49    66    73    54    47
#
# [1 rows x 21 columns]

# %%
#Let's turn the hits object into a Pandas dataframe
df_hits_BH = pandas.DataFrame(hits_BH, index = ['hits'])
df_hits_BH
# Out:
#       2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  2010  2011  \
# hits    91   115    77    70    52    65   122    68    63    71    61    72
#
#       2012  2020  2021
# hits    34    63   101

# %%
#probably want to transpose it
df_hits.T
# Out:
#       hits
# 2000   179
# 2001   145
# 2002   151
# 2003   132
# 2004   137
# 2005   106
# 2006   171
# 2007   101
# 2008   115
# 2009   134
# 2010    95
# 2011    89
# 2012    67
# 2013   119
# 2014   150
# 2016    47
# 2017    49
# 2018    66
# 2019    73
# 2020    54
# 2021    47

# %% [markdown]
# # Exercises:
#
# Do your thing!
#
# Play around a little first with the small dataframe we made above.
#
# - What is the total word count for these 10 articles?
# - What is the average word count per article for this date range?
#
# With the `hits` object:
# - Produce a graph visualizing these data. What year had the most hits for your search term?
#
# Do something new:
# - Do the same with a comparative search term. Create a graph with two trends, to compare against each other. (Keep a narrow time frame - the API has limits.)

# %%
# What is the total word count for these 10 articles?

df_all['word_count'].sum()
# Out:
# 7448

# %%
# What is the average word count per article for the 10 articles?


df_all['word_count'].mean()
# Out:
# 744.8

# %%
# Produce a graph visualizing these data over time.

import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12,6))

sns.lineplot(y='hits', x=df_hits.T.index, data=df_hits.T, color = 'red')
sns.lineplot(y='hits', x=df_hits_BH.T.index, data=df_hits_BH.T)

ax.set_facecolor('white') #set background as white

#remove spines around the chart
ax.spines['top'].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

plt.xlabel('') #year is obvious, we don't need the label
plt.xticks(fontsize=14, family='serif') #set font and size of year on x-axis

plt.ylabel('Counts of hits', fontsize=14, family='serif') #set y-label
plt.yticks(fontsize=12, family='serif') #set font and size of year on x-axis

#control ticks
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=True) # labels along the bottom edge are on

plt.tick_params(
    axis='y',          # changes apply to the y-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the left edge are off
    labelbottom=True) # labels along the bottom edge are on

plt.tight_layout() #make sure the layout is efficient
